# %%
import numpy as np

# %%
x = np.load('regression_data.npz')

# %%
x

# %%
print(x)

# %%
lst = x.files
for item in lst:
    print(item)
    print(x[item])
# Out:
# y
# [[ 4.54920375]
#  [ 0.37198557]
#  [ 0.71130797]
#  [-0.01321289]
#  [ 2.25547326]
#  [ 1.00991575]
#  [ 3.74467594]
#  [ 0.42459277]
#  [ 1.32283365]
#  [ 0.27829829]
#  [ 0.26722913]
#  [ 2.20011229]
#  [ 1.20060998]
#  [ 0.4399717 ]
#  [ 2.62858043]
#  [ 0.50377482]
#  [ 1.94252531]
#  [ 0.57913395]
#  [ 0.67087442]
#  [ 0.37735376]]
# x
# [[ 2.08397043]
#  [-0.82101807]
#  [-0.6178707 ]
#  [-1.18382261]
#  [ 0.27408744]
#  [ 0.59944173]
#  [ 1.76889792]
#  [-0.46564555]
#  [ 0.58885278]
#  [-0.83298221]
#  [-0.51210653]
#  [ 0.27788314]
#  [-0.06587043]
#  [-0.82141236]
#  [ 0.18539944]
#  [-0.85829617]
#  [ 0.37078663]
#  [-1.40986916]
#  [-0.14466841]
#  [-0.55329962]]
# xstar
# [[-2.  ]
#  [-1.96]
#  [-1.92]
#  [-1.88]
#  [-1.84]
#  [-1.8 ]
#  [-1.76]
#  [-1.72]
#  [-1.68]
#  [-1.64]
#  [-1.6 ]
#  [-1.56]
#  [-1.52]
#  [-1.48]
#  [-1.44]
#  [-1.4 ]
#  [-1.36]
#  [-1.32]
#  [-1.28]
#  [-1.24]
#  [-1.2 ]
#  [-1.16]
#  [-1.12]
#  [-1.08]
#  [-1.04]
#  [-1.  ]
#  [-0.96]
# ...
